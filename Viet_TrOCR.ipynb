# %% [markdown]
# **INTERFACE**

# %%
from google.colab import drive
drive.mount('/content/drive')

# Copy code + interface to local SSD
# !cp -r "/content/drive/MyDrive/OCR/code" "/content/trocr_viet"
# !cp -r "/content/drive/MyDrive/OCR/interface" "/content/trocr_viet/interface"
# !touch /content/trocr_viet/data/__init__.py
# !touch /content/trocr_viet/core/__init__.py
print("✅ Ready")
# !ls /content/trocr_viet/interface/modules/
# Out:
# Mounted at /content/drive
# ✅ Ready
# __init__.py	   post_processor.py  text_detector.py
# line_segmenter.py  preprocessor.py    text_recognizer.py

# %%
# !pip install -q gradio transformers Pillow opencv-python-headless \
    scikit-learn pyvi jiwer
# !pip install -q "python-doctr[torch]"

# !python -c "import doctr; print('✅ docTR', doctr.__version__)"
# !python -c "import gradio; print('✅ gradio', gradio.__version__)"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 59.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 98.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.8 MB/s eta 0:00:00
# WARNING: python-doctr 1.0.1 does not provide the extra 'torch'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 22.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 97.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 56.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 116.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.9/288.9 kB 29.5 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
# ✅ docTR v1.0.1
# ✅ gradio 5.50.0

# %%
# %cd /content/trocr_viet/interface
# !python app.py \
    --model_path /content/drive/MyDrive/OCR/checkpoints/final_model \
    --share
# Out:
# /content/trocr_viet/interface
# /content/trocr_viet/interface/app.py:210: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(
# /content/trocr_viet/interface/app.py:210: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(
# 08:39:34 [INFO] HTTP Request: HEAD https://huggingface.co/api/telemetry/https%3A/api.gradio.app/gradio-initiated-analytics "HTTP/1.1 200 OK"
# 08:39:34 [INFO] HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 08:39:34 [INFO] NumExpr defaulting to 2 threads.
# * Running on local URL:  http://0.0.0.0:7860
# 08:39:37 [INFO] HTTP Request: GET http://localhost:7860/gradio_api/startup-events "HTTP/1.1 200 OK"
# 08:39:37 [INFO] HTTP Request: HEAD http://localhost:7860/ "HTTP/1.1 200 OK"
# 08:39:38 [INFO] HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# 08:39:38 [INFO] HTTP Request: GET https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_linux_amd64 "HTTP/1.1 200 OK"
# * Running on public URL: https://67b6bd38c82b09f5e1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 08:39:39 [INFO] HTTP Request: HEAD https://huggingface.co/api/telemetry/https%3A/api.gradio.app/gradio-launched-telemetry "HTTP/1.1 200 OK"
# 08:40:57 [INFO] [App] Initializing pipeline with new config...
# 08:40:57 [INFO] ============================================================
# 08:40:57 [INFO] Initializing Vietnamese OCR Pipeline
# 08:40:57 [INFO] ============================================================
# 08:40:57 [INFO] [Init] ✓ Preprocessor
# Downloading https://doctr-static.mindee.com/models?id=v0.7.0/db_resnet50-79bd7d70.pt&src=0 to /root/.cache/doctr/models/db_resnet50-79bd7d70.pt
# 08:41:05 [INFO] [TextDetector] Loaded db_resnet50 (GPU=True)
# 08:41:05 [INFO] [Init] ✓ TextDetector (available=True)
# 08:41:05 [INFO] [Init] ✓ LineSegmenter
# 08:41:10 [INFO] [TextRecognizer] Loading from /content/drive/MyDrive/OCR/checkpoints/final_model
# 08:41:50 [INFO] [TextRecognizer] Loaded — VRAM ≈ 770MB
# 08:41:50 [INFO] [Init] ✓ TextRecognizer
# 08:41:50 [INFO] [PostProcessor] RegexSanitizer loaded
# 08:41:50 [INFO] [AddressCorrector] Loaded gazetteer: 63 provinces, 705 districts, 10599 wards | 7538 unique names
# 08:41:50 [INFO] [PostProcessor] AddressCorrector loaded from /content/trocr_viet/data/vietnam_gazetteer.json
# 08:41:50 [INFO] [Init] ✓ PostProcessor
# 08:41:50 [INFO] [Init] Pipeline ready in 52.7s
# 08:41:50 [INFO] [Pipeline] Step 1/5: Preprocessing (CLAHE + Deskew)...
# 08:41:50 [INFO] [Pipeline] Step 2/5: Detecting text regions (DBNet++)...
# 08:41:52 [INFO] [TextDetector] Detected 18 text regions
# 08:41:52 [INFO] [Pipeline] Step 3/5: Segmenting text lines (DBSCAN)...
# 08:41:52 [INFO] [LineSegmenter] Grouped 18 boxes into 2 lines (eps=40.5)
# 08:41:52 [INFO] [Pipeline] Step 4/5: Recognizing 2 lines (TrOCR)...
# 08:41:54 [INFO] [TextRecognizer] Recognized 2 lines in 1 batches
# 08:41:54 [INFO] [Pipeline] Step 5/5: Post-processing (Sanitize + Address Correction)...
# 08:41:54 [INFO] [Pipeline] Done — 2 lines in 4.00s
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3043, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trocr_viet/interface/app.py", line 366, in <module>
#     demo.launch(
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2950, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3047, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/usr/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 0.0.0.0:7860 <> https://67b6bd38c82b09f5e1.gradio.live

# %% [markdown]
# **FINE TUNNING**

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# Create an lmdb folder on your local Colab SSD.
os.makedirs('/content/lmdb', exist_ok=True)

# Copy the LMDB from the drive to the SSD.
# !cp -r "/content/drive/MyDrive/OCR/lmdb/." "/content/lmdb/"
print("Data copying is complete. Local directory structure:")
# !ls /content/lmdb/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ^C
# Data copying is complete. Local directory structure:
# word_printed

# %%
# Install the library from requirements.txt
# !pip install -r /content/drive/MyDrive/OCR/code/requirements.txt

# Copy the code folder to the /content directory.
# !cp -r "/content/drive/MyDrive/OCR/code" "/content/trocr_viet"

# Move the terminal cursor to the code directory.
# %cd /content/trocr_viet
# !touch data/__init__.py
# !touch core/__init__.py
# Out:
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 5)) (0.25.0+cu128)
# Requirement already satisfied: transformers>=4.35.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: tokenizers>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 7)) (0.22.2)
# Requirement already satisfied: datasets>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (4.0.0)
# Collecting lmdb>=1.4.1 (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 9))
#   Downloading lmdb-2.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: Pillow>=9.5.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: opencv-python-headless>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 12)) (4.13.0.92)
# Requirement already satisfied: albumentations>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (2.0.8)
# Collecting jiwer>=3.0.3 (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 14))
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 15)) (6.0.3)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/OCR/code/requirements.txt (line 16)) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (26.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (0.70.16)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (6.5.16)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer>=3.0.3->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 14)) (8.3.3)
# Collecting rapidfuzz>=3.9.7 (from jiwer>=3.0.3->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 14))
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations>=1.3.1->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.14.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.35.0->-r /content/drive/MyDrive/OCR/code/requirements.txt (line 6)) (0.1.2)
# Downloading lmdb-2.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (333 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 10.0 MB/s eta 0:00:00
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, lmdb, jiwer
# Successfully installed jiwer-4.0.0 lmdb-2.2.0 rapidfuzz-3.14.5
# /content/trocr_viet

# %%
# Remove the Google Drive Mount block in main.py using sed.
# !sed -i '/# ── Google Drive Mount/,/logger.info("Not in Colab/ s/^/# /' /content/trocr_viet/main.py

# %%
# !python main.py --stage all
# !python main.py --stage 1
# !python main.py --stage 2a --config config.yaml
# !python main.py --stage 2b
# Out:
# 2026-04-29 06:17:07,586 [INFO] __main__ — ======================================================================
# 2026-04-29 06:17:08,076 [INFO] __main__ — TrOCR Vietnamese | stage=2b | model=microsoft/trocr-base-stage1
# 2026-04-29 06:17:08,076 [INFO] __main__ — ======================================================================
# 2026-04-29 06:17:08,106 [INFO] __main__ — GPU: NVIDIA L4 | VRAM: 23.7 GB
# 2026-04-29 06:17:08,109 [INFO] __main__ — [Setup] Loading base model: microsoft/trocr-base-stage1
# 2026-04-29 06:17:08,308 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:08,321 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:08,334 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 1.12kB [00:00, 4.15MB/s]
# 2026-04-29 06:17:08,431 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:08,567 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-29 06:17:08,683 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:08,696 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/vocab.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:08,710 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/vocab.json "HTTP/1.1 200 OK"
# vocab.json: 899kB [00:00, 34.9MB/s]
# 2026-04-29 06:17:08,839 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:08,851 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/merges.txt "HTTP/1.1 200 OK"
# 2026-04-29 06:17:08,865 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/merges.txt "HTTP/1.1 200 OK"
# merges.txt: 456kB [00:00, 100MB/s]
# 2026-04-29 06:17:08,971 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/tokenizer.json "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-29 06:17:08,971 [WARNING] huggingface_hub.utils._http — Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-29 06:17:09,092 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:09,229 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:09,243 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/special_tokens_map.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:09,256 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/special_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 772/772 [00:00<00:00, 5.43MB/s]
# 2026-04-29 06:17:09,358 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:09,561 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:09,654 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:09,771 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/chat_template.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:09,878 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:09,977 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/audio_tokenizer_config.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:10,071 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:10,264 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:10,278 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/preprocessor_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:10,290 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/preprocessor_config.json "HTTP/1.1 200 OK"
# preprocessor_config.json: 100% 224/224 [00:00<00:00, 1.66MB/s]
# The image processor of type `ViTImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# 2026-04-29 06:17:10,391 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:10,487 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/preprocessor_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:10,500 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/preprocessor_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:10,608 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:10,620 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:10,633 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/config.json "HTTP/1.1 200 OK"
# config.json: 4.21kB [00:00, 13.8MB/s]
# 2026-04-29 06:17:10,739 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:10,752 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:10,904 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:10,916 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:11,029 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:11,180 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-29 06:17:11,276 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/tokenizer.model "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:11,403 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:11,415 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:11,508 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:11,611 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-04-29 06:17:11,845 [INFO] __main__ — [Setup] Image processor: do_resize=False, do_normalize=True, expected input=128×1536
# 2026-04-29 06:17:11,934 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:11,948 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:12,041 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-04-29 06:17:12,231 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:12,244 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:12,356 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2026-04-29 06:17:12,481 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/models/microsoft/trocr-base-stage1/xet-read-token/59270604e602d5094b8d344298053f9fd3979dcf "HTTP/1.1 200 OK"
# model.safetensors: 100% 1.54G/1.54G [00:06<00:00, 223MB/s]
# Loading weights: 100% 476/476 [00:00<00:00, 742.97it/s, Materializing param=encoder.layernorm.weight]
# VisionEncoderDecoderModel LOAD REPORT from: microsoft/trocr-base-stage1
# Key                                                 | Status     |
# ----------------------------------------------------+------------+-
# decoder.model.decoder.embed_positions._float_tensor | UNEXPECTED |
# encoder.pooler.dense.weight                         | MISSING    |
# encoder.pooler.dense.bias                           | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# 2026-04-29 06:17:20,578 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/microsoft/trocr-base-stage1/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-29 06:17:20,591 [INFO] httpx — HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/generation_config.json "HTTP/1.1 200 OK"
# 2026-04-29 06:17:20,605 [INFO] httpx — HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/trocr-base-stage1/59270604e602d5094b8d344298053f9fd3979dcf/generation_config.json "HTTP/1.1 200 OK"
# generation_config.json: 100% 190/190 [00:00<00:00, 1.04MB/s]
# 2026-04-29 06:17:20,608 [INFO] __main__ — [Setup] Tokenizer Class: RobertaTokenizer
# 2026-04-29 06:17:22,348 [INFO] __main__ — [Setup] Vocab file: 254 tokens | Newly added to tokenizer: 254
# 2026-04-29 06:17:22,350 [INFO] __main__ — [Setup] Tokenizer validation:
#   Input : Đại học Tôn Đức Thắng - TrOCR ặ ợ ướ
#   Tokens: ['Đ', 'ạ', 'i', 'Ġ', 'h', 'ọ', 'c', 'Ġ', 'T', 'ô', 'n', 'Ġ', 'Đ', 'ứ', 'c', 'Ġ', 'T', 'h', 'ắ', 'n', 'g', 'Ġ', '-', 'Ġ', 'T', 'r', 'O', 'C', 'R', 'Ġ', 'ặ', 'Ġ', 'ợ', 'Ġ', 'ư', 'ớ']
#   IDs   : [50124, 50278, 118, 1437, 298, 50322, 438, 1437, 565, 49820, 282, 1437, 50124, 50350, 438, 1437, 565, 298, 50292, 282, 571, 1437, 12, 1437, 565, 338, 673, 347, 500, 1437, 50300, 1437, 50344, 1437, 50273, 50336]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The new lm_head weights will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# 2026-04-29 06:17:23,687 [INFO] __main__ — [Setup] Decoder embedding resized → vocab_size=50381
# 2026-04-29 06:17:23,688 [INFO] __main__ — [ViT PosEmb] Interpolating positional embeddings: (24×24) → (8×96) | embed_dim=768
# 2026-04-29 06:17:23,700 [INFO] __main__ — [ViT PosEmb] Done. New positional embeddings shape: (1, 769, 768) = 1 CLS + 768 patches
# 2026-04-29 06:17:24,342 [INFO] __main__ — [Setup] Model ready | encoder=86,800,896 params | decoder=298,448,896 params
# 2026-04-29 06:17:24,343 [INFO] __main__ — ──────────────────────────────────────────────────────────────────────
# 2026-04-29 06:17:24,343 [INFO] __main__ — STAGE 2b — Mixed HW + Printed Replay (EWC)
# 2026-04-29 06:17:24,343 [INFO] __main__ — ──────────────────────────────────────────────────────────────────────
# 2026-04-29 06:17:24,383 [INFO] data.dataset — LMDBDataset | path=/content/lmdb/line_handwritten/train | data_type=handwritten | samples=8044 | format=image-{:08d}
# 2026-04-29 06:17:24,384 [INFO] data.dataset — LMDBDataset | path=/content/lmdb/line_printed/train | data_type=printed | samples=50349 | format=image-{:08d}
# 2026-04-29 06:17:24,389 [INFO] data.dataset — LMDBDataset | path=/content/lmdb/line_printed/train | data_type=printed | samples=7552 | format=image-{:08d}
# 2026-04-29 06:17:24,390 [INFO] data.dataset — [Stage2b] HW line samples: 8044 | Printed replay: 7552 (15% of 50349)
# 2026-04-29 06:17:24,391 [INFO] data.dataset — LMDBDataset | path=/content/lmdb/line_printed/val | data_type=printed | samples=4911 | format=image-{:08d}
# 2026-04-29 06:17:24,410 [INFO] data.dataset — LMDBDataset | path=/content/lmdb/line_handwritten/val | data_type=handwritten | samples=522 | format=image-{:08d}
# 2026-04-29 06:17:24,428 [INFO] core.ewc — [EWC] Initialized with lambda=500.0 | tracked params=478
# 2026-04-29 06:18:32,597 [INFO] core.ewc — [EWC] State loaded from /content/drive/MyDrive/OCR/checkpoints/ewc_state.pt
# 2026-04-29 06:18:32,598 [INFO] core.trainer — [Stage2b] EWC state loaded from disk.
# 2026-04-29 06:18:32,604 [INFO] core.trainer — [LLRD] Optimizer built | groups=38 | trainable_params=385,249,792 | base_lr=5.00e-06
# 2026-04-29 06:19:59,401 [INFO] core.trainer — [Checkpoint] Resumed from /content/drive/MyDrive/OCR/checkpoints/stage2b_epoch_011.pt | epoch=11 | step=19296
# 2026-04-29 06:21:08,708 [INFO] core.trainer — [Stage2b] Baseline printed CER from 2a = 0.0190
# 2026-04-29 06:21:13,876 [INFO] core.trainer — [Stage2b] Restored best HW CER=0.1530 from epoch checkpoint
# 2026-04-29 06:21:13,876 [INFO] core.trainer — [Stage2b] Starting from epoch 12/25 | best_hw_cer=0.1530
# 2026-04-29 06:21:13,878 [INFO] core.trainer — [Stage2b] Turn on Gradient Checkpointing...
# Stage2b E12:   0% 0/1608 [00:00<?, ?it/s]`use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# Stage2b E12:  93% 1503/1608 [14:58<01:01,  1.71it/s]2026-04-29 06:36:13,016 [INFO] core.trainer — [Stage2b] E12 step=20800 | CE=0.1471 | EWC=0.0001 | LR=5.56e-08
# Stage2b E12:  97% 1553/1608 [15:28<00:36,  1.53it/s]2026-04-29 06:36:42,768 [INFO] core.trainer — [Stage2b] E12 step=20850 | CE=0.0806 | EWC=0.0001 | LR=5.54e-08
# Stage2b E12: 100% 1603/1608 [15:57<00:02,  1.70it/s]2026-04-29 06:37:12,388 [INFO] core.trainer — [Stage2b] E12 step=20900 | CE=0.1471 | EWC=0.0001 | LR=5.52e-08
# Stage2b E12: 100% 1608/1608 [16:01<00:00,  1.67it/s]
# 2026-04-29 06:37:15,214 [INFO] core.trainer — [Stage2b] Epoch 12 | avg_CE=0.1510 | avg_EWC=0.0001
# Eval printed:   0% 0/154 [00:00<?, ?it/s]2026-04-29 06:37:17,326 [INFO] core.trainer — [Eval DEBUG] printed first sample raw IDs (len=35): [2, 0, 487, 725, 50093, 1437, 104, 50094, 347, 725, 1437, 534, 495, 12, 565, 347, 1437, 347, 50285, 448, 1437, 510, 725, 50279, 2, 1, 1, 1, 1, 1]...
# 2026-04-29 06:40:44,640 [INFO] core.trainer —
# [DEBUG EVAL - PRINTED]
# 2026-04-29 06:40:44,640 [INFO] core.trainer — Mẫu 1 [idx=000] - Ref : NHÀ SÁCH GD-TC CẨM PHẢ
# 2026-04-29 06:40:44,640 [INFO] core.trainer — Mẫu 1 [idx=000] - Pred: NHÀ SÁCH GD-TC CẨM PHẢ
# 2026-04-29 06:40:44,640 [INFO] core.trainer — Mẫu 2 [idx=1227] - Ref : ĐC: 212 Đường Trần Phú-Cẩm Phả
# 2026-04-29 06:40:44,640 [INFO] core.trainer — Mẫu 2 [idx=1227] - Pred: ĐC: 212 Đường Trần Phú-Cẩm Phả
# 2026-04-29 06:40:44,641 [INFO] core.trainer — Mẫu 3 [idx=2455] - Ref : ngô vệ đại tướng quân.
# 2026-04-29 06:40:44,641 [INFO] core.trainer — Mẫu 3 [idx=2455] - Pred: ngô vệ đại tướng quân.
# 2026-04-29 06:40:44,641 [INFO] core.trainer — Mẫu 4 [idx=3683] - Ref : thành phố đón nhận một lượng lớn những di dân từ miền Bắc cùng làn
# 2026-04-29 06:40:44,641 [INFO] core.trainer — Mẫu 4 [idx=3683] - Pred: thành phố đón nhận một lượng lớn những di dân từ miền Bắc cùng làn
# 2026-04-29 06:40:44,641 [INFO] core.trainer — Mẫu 5 [idx=4910] - Ref : Ngày 1 tháng 10 năm 2009
# 2026-04-29 06:40:44,641 [INFO] core.trainer — Mẫu 5 [idx=4910] - Pred: Ngày 1 tháng 10 năm 2009
# 2026-04-29 06:40:44,641 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 06:40:44,641 [INFO] core.trainer —
# [HARD NEGATIVES - PRINTED - TOP 5 TỆ NHẤT]
# 2026-04-29 06:40:44,797 [INFO] core.trainer — Top 1 [idx=313 | CER=7.0000]
# 2026-04-29 06:40:44,797 [INFO] core.trainer —   Ref : Ngày: 14.07.2020
# 2026-04-29 06:40:44,797 [INFO] core.trainer —   Pred: Ngày : 14.07/202) (1116 riền : 12 - 12 - - - - - - - 12 - - - - - - - - 12 - - - - - - - - - 12 - - - - - - - - 12 - - - - - -
# 2026-04-29 06:40:44,797 [INFO] core.trainer — Top 2 [idx=4681 | CER=5.8000]
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Ref : Bio-Organics...
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Pred: Bio-Organics..........................................................................................
# 2026-04-29 06:40:44,798 [INFO] core.trainer — Top 3 [idx=590 | CER=5.7500]
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Ref : Ngày
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Pred: Ngày: 07/08/2020 : 20:16:33
# 2026-04-29 06:40:44,798 [INFO] core.trainer — Top 4 [idx=594 | CER=4.0000]
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Ref : Ngày
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Pred: Ngày : QUB / 16/2018
# 2026-04-29 06:40:44,798 [INFO] core.trainer — Top 5 [idx=850 | CER=3.7000]
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Ref : ĐT 0333863328 - Fax 0333863328
# 2026-04-29 06:40:44,798 [INFO] core.trainer —   Pred: ĐT 0333B36363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363
# 2026-04-29 06:40:44,798 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 06:40:44,965 [INFO] core.trainer — [Eval] PRINTED | CER=0.0217 | WER=0.0532
# Eval handwritten:   0% 0/17 [00:00<?, ?it/s]2026-04-29 06:40:48,430 [INFO] core.trainer — [Eval DEBUG] handwritten first sample raw IDs (len=129): [2, 0, 565, 338, 50273, 50336, 438, 1437, 50125, 49078, 6, 1437, 29, 1376, 282, 571, 1437, 176, 398, 1437, 12, 1437, 246, 1437, 12, 1437, 176, 288, 288, 306]...
# 2026-04-29 06:41:18,484 [INFO] core.trainer —
# [DEBUG EVAL - HANDWRITTEN]
# 2026-04-29 06:41:18,484 [INFO] core.trainer — Mẫu 1 [idx=000] - Ref : Trước đó, sáng 28 - 3 - 2004 chúng tôi rong ruổi theo chiếc xe 43H-016... ì ạch trên đường
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 1 [idx=000] - Pred: Trước đó, sáng 28 - 3 - 2004 khúng tôi rong ruổi trên chiếc xe 43H -016 -......................................................
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 2 [idx=130] - Ref : Ban quản lý lao động và chuyên gia tại Malaysia (ở Kuala Lumpur), đói và
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 2 [idx=130] - Pred: Ban quản lý lao động và chuyên gia đại Malaysia (ở Kuala Lunguyn), đói và
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 3 [idx=261] - Ref : nghèo vùng lũ... Cái mất, cái còn. Ông Ba Phước vóc người
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 3 [idx=261] - Pred: nghèo nàng lũ.................. Các mất, các còn. Ông Ba Phước vóc người
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 4 [idx=391] - Ref : TP.HCM vừa đề nghị Quĩ hỗ trợ phát triển cho TP vay 500 tỉ đồng
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 4 [idx=391] - Pred: TP.HCM vừa đề nghị Quĩ hỗ trợ phát triển cho TP vay 500 tỉ đồng
# 2026-04-29 06:41:18,485 [INFO] core.trainer — Mẫu 5 [idx=521] - Ref : 168 Ngô Gia Tự, thành phố Hà Tĩnh
# 2026-04-29 06:41:18,486 [INFO] core.trainer — Mẫu 5 [idx=521] - Pred: 468 Ngô Gia Tự, Thành phố Hà Tĩnh
# 2026-04-29 06:41:18,486 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 06:41:18,486 [INFO] core.trainer —
# [HARD NEGATIVES - HANDWRITTEN - TOP 5 TỆ NHẤT]
# 2026-04-29 06:41:18,513 [INFO] core.trainer — Top 1 [idx=389 | CER=2.4324]
# 2026-04-29 06:41:18,513 [INFO] core.trainer —   Ref : nhét túi của CSGT chưa đến 20 giây...
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Pred: nhét túi của CSGT chưa đến 20 giây.............................................................................................
# 2026-04-29 06:41:18,514 [INFO] core.trainer — Top 2 [idx=432 | CER=2.3077]
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Ref : trường hợp " không nhờ cấp cứu đã... ".
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Pred: trường hợp " không nhờ cấp cứu đã..............................................................................................
# 2026-04-29 06:41:18,514 [INFO] core.trainer — Top 3 [idx=194 | CER=1.6875]
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Ref : các quốc gia, những cuộc đối thoại trực tuyến...
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Pred: các quốc ga, những cuộc đối thoại trực tuyến...................................................................................
# 2026-04-29 06:41:18,514 [INFO] core.trainer — Top 4 [idx=148 | CER=1.3816]
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Ref : Trại Kem Kjang... 864 giờ khắc khoải Ngày 25 - 10 - 2003, chúng tôi ngơ ngác
# 2026-04-29 06:41:18,514 [INFO] core.trainer —   Pred: Trại Kem Kjang.......................................................................................... 866664 giờ khắc khoải
# 2026-04-29 06:41:18,515 [INFO] core.trainer — Top 5 [idx=046 | CER=1.3617]
# 2026-04-29 06:41:18,515 [INFO] core.trainer —   Ref : trong khu vực) để có cơ sở quản lý giá; quản lý
# 2026-04-29 06:41:18,515 [INFO] core.trainer —   Pred: Trong huộc) đã " sá cơ ở quản hóa, quản lý thâu cũng ứng sử thọ thuy đước tại cơ kháu chữa
# 2026-04-29 06:41:18,515 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 06:41:18,547 [INFO] core.trainer — [Eval] HANDWRITTEN | CER=0.1467 | WER=0.2677
# 2026-04-29 06:41:18,549 [INFO] core.trainer — [Stage2b] Smoothed HW CER (window=3): 0.1467
# 2026-04-29 06:42:54,913 [INFO] core.trainer — [Checkpoint] Saved: /content/drive/MyDrive/OCR/checkpoints/stage2b_best.pt
# 2026-04-29 06:42:54,914 [INFO] core.trainer — [Stage2b] New best HW CER=0.1467 (printed=0.0217)
# 2026-04-29 06:45:00,897 [INFO] core.ewc — [EWC] State saved to /content/drive/MyDrive/OCR/checkpoints/ewc_state.pt
# 2026-04-29 06:45:00,898 [INFO] core.trainer — [Checkpoint] Saved: /content/drive/MyDrive/OCR/checkpoints/stage2b_epoch_012.pt
# 2026-04-29 06:45:01,290 [INFO] core.trainer — [Stage2b] Turn on Gradient Checkpointing...
# Stage2b E13:   3% 45/1608 [00:28<15:18,  1.70it/s]2026-04-29 06:45:30,349 [INFO] core.trainer — [Stage2b] E13 step=20950 | CE=0.1365 | EWC=0.0001 | LR=5.50e-08
# Stage2b E13:   6% 95/1608 [00:58<14:40,  1.72it/s]2026-04-29 06:46:00,369 [INFO] core.trainer — [Stage2b] E13 step=21000 | CE=0.1079 | EWC=0.0001 | LR=5.48e-08
# Stage2b E13:   9% 145/1608 [01:28<14:42,  1.66it/s]2026-04-29 06:46:30,036 [INFO] core.trainer — [Stage2b] E13 step=21050 | CE=0.1268 | EWC=0.0001 | LR=5.46e-08
# Stage2b E13:  12% 195/1608 [01:57<14:07,  1.67it/s]2026-04-29 06:46:59,834 [INFO] core.trainer — [Stage2b] E13 step=21100 | CE=0.1422 | EWC=0.0001 | LR=5.44e-08
# Stage2b E13:  15% 245/1608 [02:27<13:12,  1.72it/s]2026-04-29 06:47:29,466 [INFO] core.trainer — [Stage2b] E13 step=21150 | CE=0.0755 | EWC=0.0001 | LR=5.41e-08
# Stage2b E13:  18% 295/1608 [02:57<12:41,  1.72it/s]2026-04-29 06:47:59,309 [INFO] core.trainer — [Stage2b] E13 step=21200 | CE=0.0835 | EWC=0.0001 | LR=5.39e-08
# Stage2b E13:  21% 345/1608 [03:27<12:40,  1.66it/s]2026-04-29 06:48:28,998 [INFO] core.trainer — [Stage2b] E13 step=21250 | CE=0.2109 | EWC=0.0001 | LR=5.37e-08
# Stage2b E13:  25% 395/1608 [03:56<11:54,  1.70it/s]2026-04-29 06:48:58,786 [INFO] core.trainer — [Stage2b] E13 step=21300 | CE=0.1026 | EWC=0.0001 | LR=5.35e-08
# Stage2b E13:  28% 445/1608 [04:26<11:15,  1.72it/s]2026-04-29 06:49:28,519 [INFO] core.trainer — [Stage2b] E13 step=21350 | CE=0.1971 | EWC=0.0001 | LR=5.33e-08
# Stage2b E13:  31% 495/1608 [04:56<10:45,  1.72it/s]2026-04-29 06:49:58,401 [INFO] core.trainer — [Stage2b] E13 step=21400 | CE=0.2030 | EWC=0.0001 | LR=5.30e-08
# Stage2b E13:  34% 545/1608 [05:26<10:40,  1.66it/s]2026-04-29 06:50:28,093 [INFO] core.trainer — [Stage2b] E13 step=21450 | CE=0.1328 | EWC=0.0001 | LR=5.28e-08
# Stage2b E13:  84% 1345/1608 [13:22<02:38,  1.66it/s]2026-04-29 06:58:24,209 [INFO] core.trainer — [Stage2b] E13 step=22250 | CE=0.1980 | EWC=0.0002 | LR=4.94e-08
# Stage2b E13:  87% 1395/1608 [13:52<02:05,  1.70it/s]2026-04-29 06:58:53,998 [INFO] core.trainer — [Stage2b] E13 step=22300 | CE=0.1659 | EWC=0.0002 | LR=4.91e-08
# Stage2b E13:  90% 1445/1608 [14:21<01:34,  1.72it/s]2026-04-29 06:59:23,707 [INFO] core.trainer — [Stage2b] E13 step=22350 | CE=0.0480 | EWC=0.0002 | LR=4.89e-08
# Stage2b E13:  93% 1495/1608 [14:51<01:05,  1.73it/s]2026-04-29 06:59:53,594 [INFO] core.trainer — [Stage2b] E13 step=22400 | CE=0.2556 | EWC=0.0002 | LR=4.87e-08
# Stage2b E13:  96% 1545/1608 [15:21<00:37,  1.66it/s]2026-04-29 07:00:23,270 [INFO] core.trainer — [Stage2b] E13 step=22450 | CE=0.2197 | EWC=0.0002 | LR=4.85e-08
# Stage2b E13:  99% 1595/1608 [15:51<00:07,  1.67it/s]2026-04-29 07:00:53,012 [INFO] core.trainer — [Stage2b] E13 step=22500 | CE=0.1039 | EWC=0.0002 | LR=4.83e-08
# Stage2b E13: 100% 1608/1608 [15:59<00:00,  1.68it/s]
# 2026-04-29 07:01:00,391 [INFO] core.trainer — [Stage2b] Epoch 13 | avg_CE=0.1453 | avg_EWC=0.0001
# Eval printed:   0% 0/154 [00:00<?, ?it/s]2026-04-29 07:01:01,814 [INFO] core.trainer — [Eval DEBUG] printed first sample raw IDs (len=35): [2, 0, 487, 725, 50093, 1437, 104, 50094, 347, 725, 1437, 534, 495, 12, 565, 347, 1437, 347, 50285, 448, 1437, 510, 725, 50279, 2, 1, 1, 1, 1, 1]...
# 2026-04-29 07:04:29,929 [INFO] core.trainer —
# [DEBUG EVAL - PRINTED]
# 2026-04-29 07:04:29,930 [INFO] core.trainer — Mẫu 1 [idx=000] - Ref : NHÀ SÁCH GD-TC CẨM PHẢ
# 2026-04-29 07:04:29,930 [INFO] core.trainer — Mẫu 1 [idx=000] - Pred: NHÀ SÁCH GD-TC CẨM PHẢ
# 2026-04-29 07:04:29,930 [INFO] core.trainer — Mẫu 2 [idx=1227] - Ref : ĐC: 212 Đường Trần Phú-Cẩm Phả
# 2026-04-29 07:04:29,930 [INFO] core.trainer — Mẫu 2 [idx=1227] - Pred: ĐC: 212 Đường Trần Phú-Cẩm Phả
# 2026-04-29 07:04:29,930 [INFO] core.trainer — Mẫu 3 [idx=2455] - Ref : ngô vệ đại tướng quân.
# 2026-04-29 07:04:29,930 [INFO] core.trainer — Mẫu 3 [idx=2455] - Pred: ngô vệ đại tướng quân.
# 2026-04-29 07:04:29,931 [INFO] core.trainer — Mẫu 4 [idx=3683] - Ref : thành phố đón nhận một lượng lớn những di dân từ miền Bắc cùng làn
# 2026-04-29 07:04:29,931 [INFO] core.trainer — Mẫu 4 [idx=3683] - Pred: thành phố đón nhận một lượng lớn những di dân từ miền Bắc cùng làn
# 2026-04-29 07:04:29,931 [INFO] core.trainer — Mẫu 5 [idx=4910] - Ref : Ngày 1 tháng 10 năm 2009
# 2026-04-29 07:04:29,931 [INFO] core.trainer — Mẫu 5 [idx=4910] - Pred: Ngày 1 tháng 10 năm 2009
# 2026-04-29 07:04:29,931 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 07:04:29,931 [INFO] core.trainer —
# [HARD NEGATIVES - PRINTED - TOP 5 TỆ NHẤT]
# 2026-04-29 07:04:30,071 [INFO] core.trainer — Top 1 [idx=313 | CER=7.0625]
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Ref : Ngày: 14.07.2020
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Pred: Ngày : 14.07/202) (1116 riền : 12 - 12 - - - 12 - - - - 12 - - - 12 - - - 12 - - 12 - - 12 - - - 12 - - 12 - - 12 - - 12 - - 12
# 2026-04-29 07:04:30,072 [INFO] core.trainer — Top 2 [idx=590 | CER=5.7500]
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Ref : Ngày
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Pred: Ngày: 07/08/2020 : 20:16:33
# 2026-04-29 07:04:30,072 [INFO] core.trainer — Top 3 [idx=4681 | CER=5.6667]
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Ref : Bio-Organics...
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Pred: Bio-Organics........................................................................................
# 2026-04-29 07:04:30,072 [INFO] core.trainer — Top 4 [idx=850 | CER=3.7000]
# 2026-04-29 07:04:30,072 [INFO] core.trainer —   Ref : ĐT 0333863328 - Fax 0333863328
# 2026-04-29 07:04:30,073 [INFO] core.trainer —   Pred: ĐT 0333B36363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363636363
# 2026-04-29 07:04:30,073 [INFO] core.trainer — Top 5 [idx=594 | CER=3.0000]
# 2026-04-29 07:04:30,073 [INFO] core.trainer —   Ref : Ngày
# 2026-04-29 07:04:30,073 [INFO] core.trainer —   Pred: Ngày : QUB Q/ CH
# 2026-04-29 07:04:30,073 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 07:04:30,242 [INFO] core.trainer — [Eval] PRINTED | CER=0.0220 | WER=0.0543
# Eval handwritten:   0% 0/17 [00:00<?, ?it/s]2026-04-29 07:04:33,722 [INFO] core.trainer — [Eval DEBUG] handwritten first sample raw IDs (len=129): [2, 0, 565, 338, 50273, 50336, 438, 1437, 50125, 49078, 6, 1437, 29, 1376, 282, 571, 1437, 176, 398, 1437, 12, 1437, 246, 1437, 12, 1437, 176, 288, 288, 306]...
# 2026-04-29 07:05:05,100 [INFO] core.trainer —
# [DEBUG EVAL - HANDWRITTEN]
# 2026-04-29 07:05:05,100 [INFO] core.trainer — Mẫu 1 [idx=000] - Ref : Trước đó, sáng 28 - 3 - 2004 chúng tôi rong ruổi theo chiếc xe 43H-016... ì ạch trên đường
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 1 [idx=000] - Pred: Trước đó, sáng 28 - 3 - 2004 khúng tôi rong riểi trên chiếc xe 43H -016 -......................................................
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 2 [idx=130] - Ref : Ban quản lý lao động và chuyên gia tại Malaysia (ở Kuala Lumpur), đói và
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 2 [idx=130] - Pred: Ban quản lý lao động và chuyên gia đại Malaysia (ở Kuala Lungu), đói và
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 3 [idx=261] - Ref : nghèo vùng lũ... Cái mất, cái còn. Ông Ba Phước vóc người
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 3 [idx=261] - Pred: nghèo nàng lũ...................... Các mất, các còn. Ông Ba Phước vóc người
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 4 [idx=391] - Ref : TP.HCM vừa đề nghị Quĩ hỗ trợ phát triển cho TP vay 500 tỉ đồng
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 4 [idx=391] - Pred: TP.HCM vừa đề nghị Quĩ hỗ trợ phát triển cho TP vay 500 tỉ đồng
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 5 [idx=521] - Ref : 168 Ngô Gia Tự, thành phố Hà Tĩnh
# 2026-04-29 07:05:05,101 [INFO] core.trainer — Mẫu 5 [idx=521] - Pred: 168 Ngô Gia Tự, Thành phố Hà Tĩnh
# 2026-04-29 07:05:05,101 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 07:05:05,102 [INFO] core.trainer —
# [HARD NEGATIVES - HANDWRITTEN - TOP 5 TỆ NHẤT]
# 2026-04-29 07:05:05,129 [INFO] core.trainer — Top 1 [idx=376 | CER=2.8529]
# 2026-04-29 07:05:05,129 [INFO] core.trainer —   Ref : CSGT kiểm tra trong giấy có... gì?
# 2026-04-29 07:05:05,129 [INFO] core.trainer —   Pred: CSGT kiểm tra trong giấy có....................................................................................................
# 2026-04-29 07:05:05,129 [INFO] core.trainer — Top 2 [idx=389 | CER=2.4324]
# 2026-04-29 07:05:05,129 [INFO] core.trainer —   Ref : nhét túi của CSGT chưa đến 20 giây...
# 2026-04-29 07:05:05,129 [INFO] core.trainer —   Pred: nhét túi của CSGT chưa đến 20 giây.............................................................................................
# 2026-04-29 07:05:05,129 [INFO] core.trainer — Top 3 [idx=432 | CER=2.3077]
# 2026-04-29 07:05:05,129 [INFO] core.trainer —   Ref : trường hợp " không nhờ cấp cứu đã... ".
# 2026-04-29 07:05:05,129 [INFO] core.trainer —   Pred: trường hợp " không nhờ cấp cứu đã..............................................................................................
# 2026-04-29 07:05:05,130 [INFO] core.trainer — Top 4 [idx=194 | CER=1.6875]
# 2026-04-29 07:05:05,130 [INFO] core.trainer —   Ref : các quốc gia, những cuộc đối thoại trực tuyến...
# 2026-04-29 07:05:05,130 [INFO] core.trainer —   Pred: các quốc ga, những cuộc đối thoại trực tuyến...................................................................................
# 2026-04-29 07:05:05,130 [INFO] core.trainer — Top 5 [idx=148 | CER=1.4342]
# 2026-04-29 07:05:05,130 [INFO] core.trainer —   Ref : Trại Kem Kjang... 864 giờ khắc khoải Ngày 25 - 10 - 2003, chúng tôi ngơ ngác
# 2026-04-29 07:05:05,130 [INFO] core.trainer —   Pred: Trại Kem Kjang......................................................................................................8666666664
# 2026-04-29 07:05:05,130 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 07:05:05,163 [INFO] core.trainer — [Eval] HANDWRITTEN | CER=0.1543 | WER=0.2690
# 2026-04-29 07:05:05,165 [INFO] core.trainer — [Stage2b] Smoothed HW CER (window=3): 0.1505
# 2026-04-29 07:06:25,478 [INFO] core.ewc — [EWC] State saved to /content/drive/MyDrive/OCR/checkpoints/ewc_state.pt
# 2026-04-29 07:06:25,479 [INFO] core.trainer — [Checkpoint] Saved: /content/drive/MyDrive/OCR/checkpoints/stage2b_epoch_013.pt
# 2026-04-29 07:06:25,627 [INFO] core.trainer — [Stage2b] Turn on Gradient Checkpointing...
# Stage2b E14:   2% 37/1608 [00:22<15:22,  1.70it/s]2026-04-29 07:06:49,133 [INFO] core.trainer — [Stage2b] E14 step=22550 | CE=0.0653 | EWC=0.0002 | LR=4.81e-08
# Stage2b E14:   5% 87/1608 [00:52<14:41,  1.73it/s]2026-04-29 07:07:19,278 [INFO] core.trainer — [Stage2b] E14 step=22600 | CE=0.0605 | EWC=0.0002 | LR=4.78e-08
# Stage2b E14:   9% 137/1608 [01:22<14:40,  1.67it/s]2026-04-29 07:07:48,885 [INFO] core.trainer — [Stage2b] E14 step=22650 | CE=0.1424 | EWC=0.0002 | LR=4.76e-08
# Stage2b E14:  12% 187/1608 [01:52<14:00,  1.69it/s]2026-04-29 07:08:18,619 [INFO] core.trainer — [Stage2b] E14 step=22700 | CE=0.1192 | EWC=0.0002 | LR=4.74e-08
# Stage2b E14:  15% 237/1608 [02:22<13:52,  1.65it/s]2026-04-29 07:08:48,480 [INFO] core.trainer — [Stage2b] E14 step=22750 | CE=0.1073 | EWC=0.0002 | LR=4.72e-08
# Stage2b E14:  18% 287/1608 [02:51<12:42,  1.73it/s]2026-04-29 07:09:18,259 [INFO] core.trainer — [Stage2b] E14 step=22800 | CE=0.1326 | EWC=0.0002 | LR=4.70e-08
# Stage2b E14:  21% 337/1608 [03:21<12:45,  1.66it/s]2026-04-29 07:09:47,888 [INFO] core.trainer — [Stage2b] E14 step=22850 | CE=0.1328 | EWC=0.0002 | LR=4.68e-08
# Stage2b E14:  24% 387/1608 [03:51<11:59,  1.70it/s]2026-04-29 07:10:17,616 [INFO] core.trainer — [Stage2b] E14 step=22900 | CE=0.1951 | EWC=0.0002 | LR=4.65e-08
# Stage2b E14:  27% 437/1608 [04:21<11:23,  1.71it/s]2026-04-29 07:10:47,379 [INFO] core.trainer — [Stage2b] E14 step=22950 | CE=0.1479 | EWC=0.0002 | LR=4.63e-08
# Stage2b E14:  30% 487/1608 [04:50<10:48,  1.73it/s]2026-04-29 07:11:17,283 [INFO] core.trainer — [Stage2b] E14 step=23000 | CE=0.0956 | EWC=0.0002 | LR=4.61e-08
# Stage2b E16:  67% 1071/1608 [10:39<05:25,  1.65it/s]2026-04-29 08:00:29,290 [INFO] core.trainer — [Stage2b] E16 step=26800 | CE=0.0468 | EWC=0.0002 | LR=3.02e-08
# Stage2b E16:  70% 1121/1608 [11:08<04:52,  1.66it/s]2026-04-29 08:00:58,861 [INFO] core.trainer — [Stage2b] E16 step=26850 | CE=0.0677 | EWC=0.0002 | LR=3.00e-08
# Stage2b E16:  73% 1171/1608 [11:38<04:17,  1.70it/s]2026-04-29 08:01:28,621 [INFO] core.trainer — [Stage2b] E16 step=26900 | CE=0.1208 | EWC=0.0002 | LR=2.98e-08
# Stage2b E16:  76% 1221/1608 [12:08<03:46,  1.71it/s]2026-04-29 08:01:58,427 [INFO] core.trainer — [Stage2b] E16 step=26950 | CE=0.1424 | EWC=0.0002 | LR=2.96e-08
# Stage2b E16:  79% 1271/1608 [12:38<03:15,  1.73it/s]2026-04-29 08:02:28,361 [INFO] core.trainer — [Stage2b] E16 step=27000 | CE=0.1720 | EWC=0.0002 | LR=2.94e-08
# Stage2b E16:  82% 1321/1608 [13:08<02:53,  1.66it/s]2026-04-29 08:02:58,111 [INFO] core.trainer — [Stage2b] E16 step=27050 | CE=0.2370 | EWC=0.0002 | LR=2.92e-08
# Stage2b E16:  85% 1371/1608 [13:37<02:19,  1.70it/s]2026-04-29 08:03:27,875 [INFO] core.trainer — [Stage2b] E16 step=27100 | CE=0.2513 | EWC=0.0002 | LR=2.90e-08
# Stage2b E16:  88% 1421/1608 [14:07<01:49,  1.71it/s]2026-04-29 08:03:57,694 [INFO] core.trainer — [Stage2b] E16 step=27150 | CE=0.2706 | EWC=0.0002 | LR=2.88e-08
# Stage2b E16:  91% 1471/1608 [14:37<01:19,  1.72it/s]2026-04-29 08:04:27,643 [INFO] core.trainer — [Stage2b] E16 step=27200 | CE=0.1075 | EWC=0.0002 | LR=2.86e-08
# Stage2b E16:  95% 1521/1608 [15:07<00:53,  1.63it/s]2026-04-29 08:04:57,376 [INFO] core.trainer — [Stage2b] E16 step=27250 | CE=0.0807 | EWC=0.0002 | LR=2.84e-08
# Stage2b E16:  98% 1571/1608 [15:36<00:21,  1.70it/s]2026-04-29 08:05:27,138 [INFO] core.trainer — [Stage2b] E16 step=27300 | CE=0.0808 | EWC=0.0002 | LR=2.82e-08
# Stage2b E16: 100% 1608/1608 [15:59<00:00,  1.68it/s]
# 2026-04-29 08:05:48,757 [INFO] core.trainer — [Stage2b] Epoch 16 | avg_CE=0.1343 | avg_EWC=0.0002
# Eval printed:   0% 0/154 [00:00<?, ?it/s]2026-04-29 08:05:50,138 [INFO] core.trainer — [Eval DEBUG] printed first sample raw IDs (len=35): [2, 0, 487, 725, 50093, 1437, 104, 50094, 347, 725, 1437, 534, 495, 12, 565, 347, 1437, 347, 50285, 448, 1437, 510, 725, 50279, 2, 1, 1, 1, 1, 1]...
# 2026-04-29 08:09:20,090 [INFO] core.trainer —
# [DEBUG EVAL - PRINTED]
# 2026-04-29 08:09:20,090 [INFO] core.trainer — Mẫu 1 [idx=000] - Ref : NHÀ SÁCH GD-TC CẨM PHẢ
# 2026-04-29 08:09:20,090 [INFO] core.trainer — Mẫu 1 [idx=000] - Pred: NHÀ SÁCH GD-TC CẨM PHẢ
# 2026-04-29 08:09:20,090 [INFO] core.trainer — Mẫu 2 [idx=1227] - Ref : ĐC: 212 Đường Trần Phú-Cẩm Phả
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 2 [idx=1227] - Pred: ĐC: 212 Đường Trần Phú-Cẩm Phả
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 3 [idx=2455] - Ref : ngô vệ đại tướng quân.
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 3 [idx=2455] - Pred: ngô vệ đại tướng quân.
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 4 [idx=3683] - Ref : thành phố đón nhận một lượng lớn những di dân từ miền Bắc cùng làn
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 4 [idx=3683] - Pred: thành phố đón nhận một lượng lớn những di dân từ miền Bắc cùng làn
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 5 [idx=4910] - Ref : Ngày 1 tháng 10 năm 2009
# 2026-04-29 08:09:20,091 [INFO] core.trainer — Mẫu 5 [idx=4910] - Pred: Ngày 1 tháng 10 năm 2009
# 2026-04-29 08:09:20,091 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 08:09:20,091 [INFO] core.trainer —
# [HARD NEGATIVES - PRINTED - TOP 5 TỆ NHẤT]
# 2026-04-29 08:09:20,235 [INFO] core.trainer — Top 1 [idx=4681 | CER=7.4667]
# 2026-04-29 08:09:20,235 [INFO] core.trainer —   Ref : Bio-Organics...
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Pred: Bio-Organics...................................................................................................................
# 2026-04-29 08:09:20,236 [INFO] core.trainer — Top 2 [idx=313 | CER=7.0625]
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Ref : Ngày: 14.07.2020
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Pred: Ngày : 14.07/202) (1116 riền : 12 - 12 - - - 12 - - - - 12 - - - 12 - - - - 12 - - - - 12 - - - - - 12 - - - - - - 12 - - - - -
# 2026-04-29 08:09:20,236 [INFO] core.trainer — Top 3 [idx=590 | CER=5.2500]
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Ref : Ngày
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Pred: Ngày: 07/08/2020 20:16:33
# 2026-04-29 08:09:20,236 [INFO] core.trainer — Top 4 [idx=594 | CER=4.2500]
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Ref : Ngày
# 2026-04-29 08:09:20,236 [INFO] core.trainer —   Pred: Ngày : QUÁ / 16/ 2U18
# 2026-04-29 08:09:20,236 [INFO] core.trainer — Top 5 [idx=850 | CER=3.7000]
# 2026-04-29 08:09:20,237 [INFO] core.trainer —   Ref : ĐT 0333863328 - Fax 0333863328
# 2026-04-29 08:09:20,237 [INFO] core.trainer —   Pred: ĐT 033333333B363636363636363636336336363363363363633363633633636333636363363363363633636336363363633363636336363636333636363336
# 2026-04-29 08:09:20,237 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 08:09:20,626 [INFO] core.trainer — [Eval] PRINTED | CER=0.0220 | WER=0.0525
# Eval handwritten:   0% 0/17 [00:00<?, ?it/s]2026-04-29 08:09:24,056 [INFO] core.trainer — [Eval DEBUG] handwritten first sample raw IDs (len=129): [2, 0, 565, 338, 50273, 50336, 438, 1437, 50125, 49078, 6, 1437, 29, 1376, 282, 571, 1437, 176, 398, 1437, 12, 1437, 246, 1437, 12, 1437, 176, 288, 288, 306]...
# 2026-04-29 08:09:55,048 [INFO] core.trainer —
# [DEBUG EVAL - HANDWRITTEN]
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 1 [idx=000] - Ref : Trước đó, sáng 28 - 3 - 2004 chúng tôi rong ruổi theo chiếc xe 43H-016... ì ạch trên đường
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 1 [idx=000] - Pred: Trước đó, sáng 28 - 3 - 2004 khúng tôi rong ruổi trên chiếc xe 43H -016 -......................................................
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 2 [idx=130] - Ref : Ban quản lý lao động và chuyên gia tại Malaysia (ở Kuala Lumpur), đói và
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 2 [idx=130] - Pred: Ban quản lý lao động và chuyên gia tại Malaysia (ở Kuala Luyn ), đói và
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 3 [idx=261] - Ref : nghèo vùng lũ... Cái mất, cái còn. Ông Ba Phước vóc người
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 3 [idx=261] - Pred: nghèo nàng lũ............ Các mất, các còn. Ông Ba Phước vóc người
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 4 [idx=391] - Ref : TP.HCM vừa đề nghị Quĩ hỗ trợ phát triển cho TP vay 500 tỉ đồng
# 2026-04-29 08:09:55,049 [INFO] core.trainer — Mẫu 4 [idx=391] - Pred: TP.HCM vừa đề nghị Quĩ hỗ trợ phát triển cho TP vay 500 tỉ đồng
# 2026-04-29 08:09:55,050 [INFO] core.trainer — Mẫu 5 [idx=521] - Ref : 168 Ngô Gia Tự, thành phố Hà Tĩnh
# 2026-04-29 08:09:55,050 [INFO] core.trainer — Mẫu 5 [idx=521] - Pred: 468 Ngô Gia Tự, Thành phố Hà Tĩnh
# 2026-04-29 08:09:55,050 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 08:09:55,050 [INFO] core.trainer —
# [HARD NEGATIVES - HANDWRITTEN - TOP 5 TỆ NHẤT]
# 2026-04-29 08:09:55,077 [INFO] core.trainer — Top 1 [idx=376 | CER=2.8529]
# 2026-04-29 08:09:55,077 [INFO] core.trainer —   Ref : CSGT kiểm tra trong giấy có... gì?
# 2026-04-29 08:09:55,077 [INFO] core.trainer —   Pred: CSGT kiểm tra trong giấy có....................................................................................................
# 2026-04-29 08:09:55,077 [INFO] core.trainer — Top 2 [idx=389 | CER=2.4324]
# 2026-04-29 08:09:55,077 [INFO] core.trainer —   Ref : nhét túi của CSGT chưa đến 20 giây...
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Pred: nhét túi của CSGT chưa đến 20 giây.............................................................................................
# 2026-04-29 08:09:55,078 [INFO] core.trainer — Top 3 [idx=432 | CER=2.3077]
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Ref : trường hợp " không nhờ cấp cứu đã... ".
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Pred: trường hợp " không nhờ cấp cứu đã..............................................................................................
# 2026-04-29 08:09:55,078 [INFO] core.trainer — Top 4 [idx=194 | CER=1.6875]
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Ref : các quốc gia, những cuộc đối thoại trực tuyến...
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Pred: các quốc ga, những cuộc đối thoại trực tuyến...................................................................................
# 2026-04-29 08:09:55,078 [INFO] core.trainer — Top 5 [idx=046 | CER=1.4043]
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Ref : trong khu vực) để có cơ sở quản lý giá; quản lý
# 2026-04-29 08:09:55,078 [INFO] core.trainer —   Pred: Trong huộc) đã sát cơ 8 quản hóa, quản lý thâu cũng ứng sử thọ dụng thúc tại cơ sơ khác chữa
# 2026-04-29 08:09:55,078 [INFO] core.trainer — ------------------------------------------------------------
#
# 2026-04-29 08:09:55,112 [INFO] core.trainer — [Eval] HANDWRITTEN | CER=0.1469 | WER=0.2653
# 2026-04-29 08:09:55,114 [INFO] core.trainer — [Stage2b] Smoothed HW CER (window=3): 0.1454
# 2026-04-29 08:10:16,834 [INFO] core.ewc — [EWC] State saved to /content/drive/MyDrive/OCR/checkpoints/ewc_state.pt
# 2026-04-29 08:10:16,835 [INFO] core.trainer — [Checkpoint] Saved: /content/drive/MyDrive/OCR/checkpoints/stage2b_epoch_016.pt
# 2026-04-29 08:10:18,429 [INFO] core.trainer — [Stage2b] Turn on Gradient Checkpointing...
# Stage2b E17:   1% 13/1608 [00:08<15:34,  1.71it/s]2026-04-29 08:10:27,441 [INFO] core.trainer — [Stage2b] E17 step=27350 | CE=0.0434 | EWC=0.0002 | LR=2.80e-08
# Stage2b E17:   4% 63/1608 [00:38<15:12,  1.69it/s]2026-04-29 08:10:57,844 [INFO] core.trainer — [Stage2b] E17 step=27400 | CE=0.1817 | EWC=0.0002 | LR=2.78e-08
# Stage2b E17:   7% 113/1608 [01:08<15:15,  1.63it/s]2026-04-29 08:11:27,786 [INFO] core.trainer — [Stage2b] E17 step=27450 | CE=0.2443 | EWC=0.0002 | LR=2.76e-08
# Stage2b E17:  10% 163/1608 [01:38<14:10,  1.70it/s]2026-04-29 08:11:57,502 [INFO] core.trainer — [Stage2b] E17 step=27500 | CE=0.0878 | EWC=0.0002 | LR=2.74e-08
# Stage2b E17:  13% 213/1608 [02:08<13:35,  1.71it/s]2026-04-29 08:12:27,127 [INFO] core.trainer — [Stage2b] E17 step=27550 | CE=0.0506 | EWC=0.0002 | LR=2.72e-08
# Stage2b E17:  16% 263/1608 [02:37<13:01,  1.72it/s]2026-04-29 08:12:57,127 [INFO] core.trainer — [Stage2b] E17 step=27600 | CE=0.1031 | EWC=0.0002 | LR=2.70e-08
# Stage2b E17:  19% 313/1608 [03:07<12:58,  1.66it/s]2026-04-29 08:13:26,805 [INFO] core.trainer — [Stage2b] E17 step=27650 | CE=0.1093 | EWC=0.0002 | LR=2.68e-08
# Stage2b E17:  23% 363/1608 [03:37<12:12,  1.70it/s]2026-04-29 08:13:56,557 [INFO] core.trainer — [Stage2b] E17 step=27700 | CE=0.1181 | EWC=0.0002 | LR=2.67e-08
# Stage2b E17:  26% 413/1608 [04:07<11:35,  1.72it/s]2026-04-29 08:14:26,301 [INFO] core.trainer — [Stage2b] E17 step=27750 | CE=0.1932 | EWC=0.0002 | LR=2.65e-08
# Stage2b E17:  29% 463/1608 [04:37<11:03,  1.73it/s]2026-04-29 08:14:56,256 [INFO] core.trainer — [Stage2b] E17 step=27800 | CE=0.1128 | EWC=0.0002 | LR=2.63e-08
# Stage2b E17:  32% 513/1608 [05:06<10:59,  1.66it/s]2026-04-29 08:15:25,981 [INFO] core.trainer — [Stage2b] E17 step=27850 | CE=0.0816 | EWC=0.0002 | LR=2.61e-08
# Stage2b E17:  35% 563/1608 [05:36<10:21,  1.68it/s]2026-04-29 08:15:55,773 [INFO] core.trainer — [Stage2b] E17 step=27900 | CE=0.0877 | EWC=0.0002 | LR=2.59e-08
# Stage2b E17:  38% 613/1608 [06:06<10:13,  1.62it/s]2026-04-29 08:16:25,535 [INFO] core.trainer — [Stage2b] E17 step=27950 | CE=0.0497 | EWC=0.0002 | LR=2.57e-08
# Stage2b E17:  41% 663/1608 [06:36<09:06,  1.73it/s]2026-04-29 08:16:55,302 [INFO] core.trainer — [Stage2b] E17 step=28000 | CE=0.1313 | EWC=0.0002 | LR=2.55e-08
# Stage2b E17:  44% 713/1608 [07:06<08:59,  1.66it/s]2026-04-29 08:17:25,043 [INFO] core.trainer — [Stage2b] E17 step=28050 | CE=0.1167 | EWC=0.0002 | LR=2.53e-08
# Stage2b E17:  47% 763/1608 [07:35<08:17,  1.70it/s]2026-04-29 08:17:54,824 [INFO] core.trainer — [Stage2b] E17 step=28100 | CE=0.0746 | EWC=0.0002 | LR=2.51e-08
# Stage2b E17:  49% 791/1608 [07:53<08:08,  1.67it/s]
# Traceback (most recent call last):
#   File "/content/trocr_viet/main.py", line 985, in <module>
#     main()
#   File "/content/trocr_viet/main.py", line 945, in main
#     trainer.train_stage2b(
#   File "/content/trocr_viet/core/trainer.py", line 1038, in train_stage2b
#     ce_loss, ewc_loss = training_step(
#                         ^^^^^^^^^^^^^^
#   File "/content/trocr_viet/core/trainer.py", line 516, in training_step
#     scale_before = scaler.get_scale()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/amp/grad_scaler.py", line 554, in get_scale
#     else cast(float, scale.item())
#                      ^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# Use to update source code from Google Drive
# %cd /content

# !rm -rf /content/trocr_viet

# !cp -r "/content/drive/MyDrive/OCR/code" "/content/trocr_viet"

# %cd /content/trocr_viet

# !touch data/__init__.py
# !touch core/__init__.py
# Out:
# /content
# /content/trocr_viet

# %% [markdown]
# **EVALUATE**

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyvi) (1.6.1)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi) (4.67.3)
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 39.2 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.0 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.12 pyvi-0.1.1 sklearn-crfsuite-0.5.0

# %%
# !python evaluate_and_analyze.py \
    --model_path /content/drive/MyDrive/OCR/checkpoints/final_model \
    --test_printed /content/lmdb/line_printed/test \
    --test_handwritten /content/lmdb/line_handwritten/test \
    --output_dir /content/drive/MyDrive/OCR/checkpoints/evaluation \
    --batch_size 4 \
    --repetition_penalty 1.2
# Out:
# 12:29:32 [INFO] ============================================================
# 12:29:32 [INFO] Vietnamese TrOCR — Evaluation & Error Analysis Pipeline
# 12:29:32 [INFO] ============================================================
# 12:29:32 [INFO] Model:              /content/drive/MyDrive/OCR/checkpoints/final_model
# 12:29:32 [INFO] Printed test:       /content/lmdb/line_printed/test
# 12:29:32 [INFO] Handwritten test:   /content/lmdb/line_handwritten/test
# 12:29:32 [INFO] Output:             /content/drive/MyDrive/OCR/checkpoints/evaluation
# 12:29:32 [INFO] Device:             cuda
# 12:29:32 [INFO] Batch size:         4
# 12:29:32 [INFO] Repetition penalty: 1.2
# 12:29:32 [INFO] Image size:         128×1536
# 12:29:32 [INFO] GPU: Tesla T4 | VRAM: 15.6GB
# 12:29:40 [INFO] NumExpr defaulting to 2 threads.
# 12:29:40 [INFO] [Model] Loading from /content/drive/MyDrive/OCR/checkpoints/final_model
# Loading weights: 100% 478/478 [00:25<00:00, 18.99it/s, Materializing param=encoder.pooler.dense.weight]
# 12:30:13 [INFO] [Model] ✓ do_resize=False verified
# 12:30:13 [INFO] [Model] ✓ decoder_start_token_id verified
# 12:30:13 [INFO] [Model] Tokenizer check: 'Đại học Tôn Đức Thắng' → ['Đ', 'ạ', 'i', 'Ġ', 'h', 'ọ', 'c', 'Ġ', 'T', 'ô']
# 12:30:27 [INFO] [Model] Materialized SinusoidalPosEmbed: (1026, 1024) → cuda
# 12:30:27 [INFO] [Model] Encoder: 86,800,896 | Decoder: 298,448,896 | VRAM≈770MB
# 12:30:27 [INFO] [PhoBERT] Loading vinai/phobert-base...
# 12:30:27 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 12:30:27 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# 12:30:27 [INFO] HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# config.json: 100% 557/557 [00:00<00:00, 2.27MB/s]
# 12:30:27 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/tokenizer_config.json "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 12:30:27 [WARNING] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 12:30:27 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/tokenizer_config.json "HTTP/1.1 404 Not Found"
# 12:30:27 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 12:30:27 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 12:30:27 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/vocab.txt "HTTP/1.1 307 Temporary Redirect"
# 12:30:27 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/vocab.txt "HTTP/1.1 200 OK"
# 12:30:27 [INFO] HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/vocab.txt "HTTP/1.1 200 OK"
# vocab.txt: 895kB [00:00, 32.2MB/s]
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/bpe.codes "HTTP/1.1 307 Temporary Redirect"
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/bpe.codes "HTTP/1.1 200 OK"
# 12:30:28 [INFO] HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/bpe.codes "HTTP/1.1 200 OK"
# bpe.codes: 1.14MB [00:00, 81.1MB/s]
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/special_tokens_map.json "HTTP/1.1 404 Not Found"
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/tokenizer.json "HTTP/1.1 200 OK"
# 12:30:28 [INFO] HTTP Request: GET https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json: 3.13MB [00:00, 131MB/s]
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 12:30:28 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# 12:30:29 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 12:30:29 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 12:30:29 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/vinai/phobert-base/c1e37c5c86f918761049cef6fa216b4779d0d01d/config.json "HTTP/1.1 200 OK"
# 12:30:29 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 12:30:29 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 12:30:29 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/pytorch_model.bin "HTTP/1.1 302 Found"
# 12:30:29 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/xet-read-token/c1e37c5c86f918761049cef6fa216b4779d0d01d "HTTP/1.1 200 OK"
# pytorch_model.bin: 100% 543M/543M [00:03<00:00, 154MB/s]
# 12:30:33 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# 12:30:33 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base "HTTP/1.1 200 OK"
# 12:30:33 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/commits/main "HTTP/1.1 200 OK"
# 12:30:33 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/discussions?p=0 "HTTP/1.1 200 OK"
# Loading weights:  35% 72/204 [00:00<00:00, 4161.25it/s, Materializing param=roberta.encoder.layer.3.intermediate.dense.weight]12:30:34 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/commits/refs%2Fpr%2F7 "HTTP/1.1 200 OK"
# Loading weights:  48% 97/204 [00:00<00:00, 3908.99it/s, Materializing param=roberta.encoder.layer.5.attention.self.key.bias]12:30:34 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/refs%2Fpr%2F7/model.safetensors.index.json "HTTP/1.1 404 Not Found"
# Loading weights:  83% 170/204 [00:00<00:00, 922.22it/s, Materializing param=roberta.encoder.layer.9.output.LayerNorm.weight]12:30:34 [INFO] HTTP Request: HEAD https://huggingface.co/vinai/phobert-base/resolve/refs%2Fpr%2F7/model.safetensors "HTTP/1.1 302 Found"
# Loading weights: 100% 204/204 [00:00<00:00, 925.47it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]
# The tied weights mapping and config for this model specifies to tie roberta.embeddings.word_embeddings.weight to lm_head.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie lm_head.bias to lm_head.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# RobertaForMaskedLM LOAD REPORT from: vinai/phobert-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.pooler.dense.weight     | UNEXPECTED |  |
# roberta.embeddings.position_ids | UNEXPECTED |  |
# roberta.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 12:30:34 [INFO] HTTP Request: GET https://huggingface.co/api/models/vinai/phobert-base/xet-read-token/92f45c73e86450797c850a26ba9410a95dd7d897 "HTTP/1.1 200 OK"
# model.safetensors:   0% 0.00/543M [00:00<?, ?B/s]12:30:34 [INFO] [PhoBERT] pyvi ViTokenizer loaded for word segmentation.
# 12:30:34 [INFO] [PhoBERT] Loaded | params=184,280,578 | VRAM≈369MB (FP16)
# 12:30:34 [INFO] [AddressCorrector] Loaded gazetteer: 63 provinces, 705 districts
# 12:30:34 [INFO]
# ============================================================
# 12:30:34 [INFO] [Eval] Domain: PRINTED
# 12:30:34 [INFO] [Eval] LMDB: /content/lmdb/line_printed/test
# 12:30:34 [INFO] ============================================================
# 12:30:34 [INFO] LMDBDataset | path=/content/lmdb/line_printed/test | data_type=printed | samples=3739 | format=image-{:08d}
# 12:30:34 [INFO] [Eval] Samples: 3739
#
# model.safetensors: 100% 543M/543M [00:03<00:00, 150MB/s]
#
# Eval printed:   0% 1/935 [00:06<1:47:33,  6.91s/it]
# Eval printed:   0% 2/935 [00:08<1:03:10,  4.06s/it]
# Eval printed:   0% 3/935 [00:10<46:00,  2.96s/it]
# Eval printed:   0% 4/935 [00:12<36:25,  2.35s/it]
# Eval printed:   1% 5/935 [00:13<32:23,  2.09s/it]
# Eval printed:   1% 6/935 [00:15<29:52,  1.93s/it]
# Eval printed:   1% 7/935 [00:16<25:38,  1.66s/it]
# Eval printed:   1% 8/935 [00:17<24:43,  1.60s/it]
# Eval printed:   1% 9/935 [00:19<24:31,  1.59s/it]
# Eval printed:   1% 10/935 [00:21<26:47,  1.74s/it]
# Eval printed:   1% 11/935 [00:23<27:40,  1.80s/it]
# Eval printed:   1% 12/935 [00:24<26:07,  1.70s/it]
# Eval printed:   1% 13/935 [00:26<24:29,  1.59s/it]
# Eval printed:   1% 14/935 [00:27<24:42,  1.61s/it]
# Eval printed:   2% 15/935 [00:29<24:09,  1.58s/it]
# Eval printed:   2% 16/935 [00:30<23:40,  1.55s/it]
# Eval printed:   2% 17/935 [00:32<23:12,  1.52s/it]
# Eval printed:   2% 18/935 [00:34<24:53,  1.63s/it]
# Eval printed:   2% 19/935 [00:40<47:25,  3.11s/it]
# Eval printed:   2% 20/935 [00:44<49:32,  3.25s/it]
# Eval printed:   2% 21/935 [00:45<41:40,  2.74s/it]
# Eval printed:   2% 22/935 [00:47<35:06,  2.31s/it]
# Eval printed:   2% 23/935 [00:48<31:56,  2.10s/it]
# 12:59:33 [INFO]     Pred: Khi hai người lên đến giáp giới tỉnh Lạng Sơn thì nghe
# 12:59:33 [INFO]     CER:  0.0000 [PERFECT]
# 12:59:33 [INFO]
# 12:59:33 [INFO]     Ref:  tin Hàn đã bị hại, Tố giật mình nói:
# 12:59:33 [INFO]     Pred: tin Hàn đã bị hại. Tố giật mình nói:
# 12:59:33 [INFO]     CER:  0.0278 [MINOR_ERROR]
# 12:59:33 [INFO]
# 12:59:33 [INFO]
# ============================================================
# 12:59:33 [INFO] [Eval] Domain: HANDWRITTEN
# 12:59:33 [INFO] [Eval] LMDB: /content/lmdb/line_handwritten/test
# 12:59:33 [INFO] ============================================================
# 12:59:33 [INFO] LMDBDataset | path=/content/lmdb/line_handwritten/test | data_type=handwritten | samples=738 | format=image-{:08d}
# 12:59:33 [INFO] [Eval] Samples: 738
# Eval handwritten: 100% 185/185 [06:26<00:00,  2.09s/it]
# 13:05:59 [INFO]
# [Eval] HANDWRITTEN Results:
# 13:05:59 [INFO]   Aggregate CER: 0.1217
# 13:05:59 [INFO]   Aggregate WER: 0.2992
# 13:05:59 [INFO]   Samples: 738 | FPS: 1.9 | Time: 386.1s
# 13:05:59 [INFO]   Peak VRAM: 1.40 GB
# 13:05:59 [INFO]   Error categories: {'MINOR_ERROR': 622, 'HALLUCINATION_LOOP': 8, 'PERFECT': 54, 'SUBSTITUTION': 53, 'TRUNCATION': 1}
# 13:05:59 [INFO]
#   Sample predictions (5):
# 13:05:59 [INFO]     Ref:  Thứ trưởng Bộ Tài nguyên & môi trường Đặng Hùng Võ tâm đắc với
# 13:05:59 [INFO]     Pred: Thứ trưởng Bộ tài nguyên và môi trường Đặng Hùng Võ tâm đắc với
# 13:05:59 [INFO]     CER:  0.0484 [MINOR_ERROR]
# 13:05:59 [INFO]
# 13:05:59 [INFO]     Ref:  cơ chế " khuyến khích nhà đầu tư thỏa thuận với người sử dụng đất để nhận
# 13:05:59 [INFO]     Pred: cơ chế"khuyến Khích nhà đầu tư thỏa thuận với người sử đất để nhận
# 13:05:59 [INFO]     CER:  0.1096 [MINOR_ERROR]
# 13:05:59 [INFO]
# 13:05:59 [INFO]     Ref:  chuyển nhượng hoặc thuê quyền sử dụng đất, nhận góp vốn bằng quyền sử
# 13:05:59 [INFO]     Pred: chuyển nhượng hoặc thuê quyền sử dụng đất, nhậu góp vốn bằng quyền sả.
# 13:05:59 [INFO]     CER:  0.0435 [MINOR_ERROR]
# 13:05:59 [INFO]
# 13:05:59 [INFO]     Ref:  dụng đất... " Nhưng tại hội nghị hôm qua, tiếng nói từ các sở tài nguyên
# 13:05:59 [INFO]     Pred: dụng đất..."Nhưng tại hội nghị hôm qua, tiếng nói bừ các sớ tài nguyên
# 13:05:59 [INFO]     CER:  0.0556 [HALLUCINATION_LOOP]
# 13:05:59 [INFO]
# 13:05:59 [INFO]     Ref:  & môi trường lại đều đồng thanh " loại bỏ " điều khoản này ra khỏi dự thảo.
# 13:05:59 [INFO]     Pred: và môi trường lại điều hành"toại bỏ"điều khoản này ra khỏi dư thảo.
# 13:05:59 [INFO]     CER:  0.2133 [MINOR_ERROR]
# 13:05:59 [INFO]
# 13:05:59 [INFO]
# [PhoBERT Impact Analysis]
# 13:05:59 [INFO]   Helped (CER improved):  199 samples
# 13:05:59 [INFO]   Hurt (CER worsened):    743 samples
# 13:05:59 [INFO]   Neutral (no change):    3535 samples
# 13:05:59 [INFO]   Avg CER delta:          +0.0054
# 13:05:59 [INFO]
# [Export] Metrics summary: /content/drive/MyDrive/OCR/checkpoints/evaluation/metrics_summary.json
# 13:06:00 [INFO] [Export] CSV: /content/drive/MyDrive/OCR/checkpoints/evaluation/error_analysis/worst_cases_report.csv
# 13:06:00 [INFO] [Export] Markdown: /content/drive/MyDrive/OCR/checkpoints/evaluation/error_analysis/worst_cases_report.md
# 13:06:00 [INFO] [Export] All predictions: /content/drive/MyDrive/OCR/checkpoints/evaluation/all_predictions.csv
# 13:06:00 [INFO]
# ============================================================
# 13:06:00 [INFO] FINAL RESULTS
# 13:06:00 [INFO] ============================================================
# 13:06:00 [INFO]   Overall CER: 0.0351
# 13:06:00 [INFO]   Overall WER: 0.1006
# 13:06:00 [INFO]   PRINTED      — CER: 0.0161 | WER: 0.0578 | Samples: 3739 | FPS: 2.2
# 13:06:00 [INFO]   HANDWRITTEN  — CER: 0.1217 | WER: 0.2992 | Samples: 738 | FPS: 1.9
# 13:06:00 [INFO]
#   Output directory: /content/drive/MyDrive/OCR/checkpoints/evaluation
# 13:06:00 [INFO] ============================================================

# %% [markdown]
# **EXTERNAL BASELINE EVALUATION**

# %%
# !pip install -q vietocr jiwer lmdb Pillow tqdm
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 69.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 68.2 MB/s eta 0:00:00
#   Building wheel for gdown (pyproject.toml) ... done
#   Building wheel for prefetch-generator (setup.py) ... done
# ✅ VietOCR installed

# %%
# %cd /content/trocr_viet
# !python evaluate_baselines.py \
    --test_printed /content/lmdb/line_printed/test \
    --test_handwritten /content/lmdb/line_handwritten/test \
    --output_dir /content/drive/MyDrive/OCR/checkpoints/baseline_eval \
    --device cuda
# Out:
# /content/trocr_viet
# 02:17:55 [INFO] ============================================================
# 02:17:55 [INFO] Multi-tier Baseline Benchmarking — Vietnamese OCR
# 02:17:55 [INFO] ============================================================
# 02:17:55 [INFO]
# [Data] Loading LMDB test sets...
# 02:17:55 [INFO]   RawLMDBReader: /content/lmdb/line_printed/test → 3739 samples
# 02:17:55 [INFO]   RawLMDBReader: /content/lmdb/line_handwritten/test → 738 samples
# 02:17:55 [INFO] [Data] Total: 3739 printed + 738 handwritten = 4477
# 02:17:55 [INFO]
# ────────────────────────────────────────────────────────────
# 02:17:55 [INFO] [Baseline 1] VietOCR (VGG + Transformer)
# 02:17:55 [INFO] ────────────────────────────────────────────────────────────
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
# 100% 548M/548M [00:05<00:00, 103MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:144: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   self.encoder = TransformerEncoder(
# 18533it [00:12, 1524.99it/s]
# 02:18:24 [INFO] [VietOCR] Loaded | params=37,650,217 | VRAM≈151MB
# 02:18:24 [INFO]   Evaluating VietOCR (VGG-Transformer) on printed (3739 samples)...
#   VietOCR (VGG-Transformer) [printed]: 100% 3739/3739 [24:51<00:00,  2.51it/s]
# 02:43:18 [INFO]   ✓ VietOCR (VGG-Transformer) [printed]: CER=0.0304 | WER=0.1014 | FPS=2.5 | 3739 samples in 1491.8s
# 02:43:18 [INFO]   Evaluating VietOCR (VGG-Transformer) on handwritten (738 samples)...
#   VietOCR (VGG-Transformer) [handwritten]: 100% 738/738 [05:30<00:00,  2.23it/s]
# 02:48:50 [INFO]   ✓ VietOCR (VGG-Transformer) [handwritten]: CER=0.2355 | WER=0.5886 | FPS=2.2 | 738 samples in 330.7s
# 02:48:50 [INFO]   Saved: /content/drive/MyDrive/OCR/checkpoints/baseline_eval/vietocr_predictions.csv
# 02:48:50 [INFO]
# ────────────────────────────────────────────────────────────
# 02:48:50 [INFO] [Baseline 2] CRNN + CTC
# 02:48:50 [INFO] ────────────────────────────────────────────────────────────
# 10935it [00:07, 1521.70it/s]
# 02:49:01 [INFO] [CRNN] Loaded vgg_seq2seq | params=22,371,113 | VRAM≈89MB
# 02:49:01 [INFO]   Evaluating CRNN-Seq2Seq (vgg_seq2seq) on printed (3739 samples)...
#   CRNN-Seq2Seq (vgg_seq2seq) [printed]: 100% 3739/3739 [04:48<00:00, 12.97it/s]
# 02:53:49 [INFO]   ✓ CRNN-Seq2Seq (vgg_seq2seq) [printed]: CER=0.0547 | WER=0.1501 | FPS=13.0 | 3739 samples in 288.2s
# 02:53:49 [INFO]   Evaluating CRNN-Seq2Seq (vgg_seq2seq) on handwritten (738 samples)...
#   CRNN-Seq2Seq (vgg_seq2seq) [handwritten]: 100% 738/738 [01:22<00:00,  8.97it/s]
# 02:55:12 [INFO]   ✓ CRNN-Seq2Seq (vgg_seq2seq) [handwritten]: CER=0.5927 | WER=0.9348 | FPS=9.0 | 738 samples in 82.2s
# 02:55:12 [INFO]   Saved: /content/drive/MyDrive/OCR/checkpoints/baseline_eval/crnn_predictions.csv
# 02:55:12 [INFO]   Saved: /content/drive/MyDrive/OCR/checkpoints/baseline_eval/baseline_metrics_summary.json
#
# ==========================================================================================
# MULTI-TIER BASELINE COMPARISON — Vietnamese OCR
# ==========================================================================================
# Model                                    CER      WER   Pr.CER   HW.CER  Pr.PERF       Params
# ------------------------------------------------------------------------------------------
# TrOCR (ours, fine-tuned)              0.0286   0.0792   0.0117   0.1057    68.5%        ~337M
# ------------------------------------------------------------------------------------------
# VietOCR (VGG-Transformer)             0.0642   0.1817   0.0304   0.2355    45.2%        37.7M
# CRNN-Seq2Seq (vgg_seq2seq)            0.1434   0.2795   0.0547   0.5927    31.9%        22.4M
# ==========================================================================================
#
# 02:55:12 [INFO]
# [Done] All outputs saved to: /content/drive/MyDrive/OCR/checkpoints/baseline_eval

# %%
import json
with open("/content/drive/MyDrive/OCR/checkpoints/baseline_eval/baseline_metrics_summary.json") as f:
    data = json.load(f)
print(json.dumps(data, indent=2, ensure_ascii=False))

# %% [markdown]
# **MANUAL FINAL MODEL EXPORT**

# %%
# =============================================================================
# Manual Final Model Export — After Early-Stopped or Individual Stage 2b
# =============================================================================
# This cell replicates the exact model initialization from main.py::setup_model()
# to ensure the exported model is identical to what the training pipeline produces.
#
# Prerequisites (run the standard setup cells from Section 5 first):
#   - Google Drive is mounted
#   - Code is copied to /content/trocr_viet/ (setup cell: cp -r .../code /content/trocr_viet)
#   - requirements.txt dependencies are installed
#   - stage2b_best.pt exists in checkpoint_dir on Google Drive
#   - Vietnamese vocab file exists at the configured path on Google Drive
# =============================================================================

import os
import sys
import unicodedata

import torch
import yaml

# ── 1. Load config ──────────────────────────────────────────────────────────
CONFIG_PATH = "/content/trocr_viet/config.yaml"

with open(CONFIG_PATH, "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[Export] Device: {device}")

# ── 2. Initialize model + processor (mirrors main.py::setup_model) ──────────
from transformers import (
    TrOCRProcessor,
    VisionEncoderDecoderModel,
    RobertaTokenizer,
)

model_name = cfg["model"]["pretrained_name"]
vocab_file = cfg["paths"]["vocab_file"]

# Step 2a: Use Slow Tokenizer (matches training — avoids tokenization drift)
slow_tokenizer = RobertaTokenizer.from_pretrained(model_name)
processor = TrOCRProcessor.from_pretrained(model_name)
processor.tokenizer = slow_tokenizer

# Step 2b: Disable processor's internal resize (we use resize_for_vit)
processor.image_processor.do_resize = False
processor.image_processor.do_normalize = True
processor.image_processor.size = {
    "height": cfg["model"]["image_height"],
    "width":  cfg["model"]["image_width"],
}

model = VisionEncoderDecoderModel.from_pretrained(model_name)
print(f"[Export] Base model: {model_name}")

# ── 3. Add Vietnamese vocab tokens (NFC-normalized, matches training) ────────
with open(vocab_file, "r", encoding="utf-8") as f:
    raw_tokens = [
        line.strip()
        for line in f
        if line.strip() and not line.startswith("#")
    ]

new_tokens = list(dict.fromkeys(
    unicodedata.normalize("NFC", t) for t in raw_tokens
))
n_added = processor.tokenizer.add_tokens(new_tokens)
print(f"[Export] Vocab: {len(new_tokens)} tokens | Newly added: {n_added}")

if n_added > 0:
    model.decoder.resize_token_embeddings(len(processor.tokenizer))
    print(f"[Export] Decoder embeddings resized → {len(processor.tokenizer)}")

# ── 4. Set special token IDs + generation config ────────────────────────────
eos_id = processor.tokenizer.eos_token_id
pad_id = processor.tokenizer.pad_token_id

model.config.decoder_start_token_id = eos_id
model.config.pad_token_id           = pad_id
model.config.eos_token_id           = eos_id

model.generation_config.decoder_start_token_id = eos_id
model.generation_config.pad_token_id           = pad_id
model.generation_config.eos_token_id           = eos_id
model.generation_config.use_cache              = True
model.generation_config.max_length           = cfg["model"]["max_target_length"]
model.generation_config.length_penalty       = 1.0
model.generation_config.num_beams            = 1

# ── 5. Interpolate ViT positional embeddings (24×24 → 8×96) ─────────────────
pos_embed   = model.encoder.embeddings.position_embeddings   # (1, 577, 768)
cls_token   = pos_embed[:, :1, :]           # (1, 1, 768)
patch_embed = pos_embed[:, 1:, :]           # (1, 576, 768)
dim         = patch_embed.shape[-1]         # 768
old_grid    = int(patch_embed.shape[1] ** 0.5)  # 24

new_h = cfg["model"]["vit_h_patches"]       # 8
new_w = cfg["model"]["vit_w_patches"]       # 96

patch_embed = patch_embed.reshape(1, old_grid, old_grid, dim).permute(0, 3, 1, 2)
patch_embed = torch.nn.functional.interpolate(
    patch_embed.float(),
    size=(new_h, new_w),
    mode="bicubic",
    align_corners=False,
)
patch_embed = patch_embed.permute(0, 2, 3, 1).reshape(1, -1, dim)
new_pos_embed = torch.cat([cls_token.float(), patch_embed], dim=1)
model.encoder.embeddings.position_embeddings = torch.nn.Parameter(new_pos_embed)

new_image_size = (new_h * 16, new_w * 16)   # (128, 1536)
model.encoder.config.image_size = new_image_size
model.encoder.embeddings.patch_embeddings.image_size = new_image_size

print(
    f"[Export] ViT pos embed: ({old_grid}×{old_grid}) → ({new_h}×{new_w}) | "
    f"image_size={new_image_size}"
)

# ── 6. Move to device + fix meta device tensors ─────────────────────────────
model = model.to(device)

for module in model.modules():
    if module.__class__.__name__ == "TrOCRSinusoidalPositionalEmbedding":
        if hasattr(module, "weights") and isinstance(module.weights, torch.Tensor):
            n_pos, d = module.weights.shape
            pad_idx = getattr(module, "padding_idx", None)
            module.weights = module.get_embedding(n_pos, d, pad_idx).to(device)
        if hasattr(module, "_float_tensor") and isinstance(
            module._float_tensor, torch.Tensor
        ):
            module._float_tensor = torch.zeros(1, device=device)

model.decoder.config.use_cache = True

# ── 7. Load Stage 2b best checkpoint ────────────────────────────────────────
ckpt_path = os.path.join(cfg["paths"]["checkpoint_dir"], "stage2b_best.pt")
assert os.path.exists(ckpt_path), f"Checkpoint not found: {ckpt_path}"

state = torch.load(ckpt_path, map_location=device)
model.load_state_dict(state["model_state"])

epoch   = state.get("epoch", "?")
metrics = state.get("metrics", {})
best_cer = state.get("best_cer", "?")
print(f"[Export] Loaded: {ckpt_path}")
print(f"[Export]   Epoch:    {epoch}")
print(f"[Export]   Metrics:  {metrics}")
print(f"[Export]   Best CER: {best_cer}")

# ── 8. Export in HuggingFace format ──────────────────────────────────────────
final_path = os.path.join(cfg["paths"]["checkpoint_dir"], "final_model")
os.makedirs(final_path, exist_ok=True)

model.save_pretrained(final_path)
processor.save_pretrained(final_path)

print(f"\n✅ Final model exported → {final_path}")
for fname in sorted(os.listdir(final_path)):
    fsize = os.path.getsize(os.path.join(final_path, fname)) / 1e6
    print(f"  {fname}: {fsize:.1f} MB")

# ── 9. Validation: reload and verify ────────────────────────────────────────
print("\n── Validation: reloading exported model ──")
test_model = VisionEncoderDecoderModel.from_pretrained(final_path).to(device)
test_processor = TrOCRProcessor.from_pretrained(final_path)

# Tokenizer round-trip check
test_str  = unicodedata.normalize("NFC", "Đại học Tôn Đức Thắng")
test_ids  = test_processor.tokenizer.encode(test_str, add_special_tokens=False)
test_toks = test_processor.tokenizer.convert_ids_to_tokens(test_ids)
print(f"  Tokenizer: '{test_str}' → {test_toks}")

# Parameter count consistency
enc_params = sum(p.numel() for p in test_model.encoder.parameters())
dec_params = sum(p.numel() for p in test_model.decoder.parameters())
print(f"  Encoder: {enc_params:,} params | Decoder: {dec_params:,} params")

# Weight identity check (random layer)
orig_w = list(model.parameters())[0].data.cpu()
load_w = list(test_model.parameters())[0].data.cpu()
assert torch.allclose(orig_w, load_w, atol=1e-6), "Weight mismatch after reload!"
print(f"  Weight identity check: PASSED")

print(f"\n✅ Validation passed — model is ready for inference.")
print(f"   Path: {final_path}")
# Out:
# [Export] Device: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]
# The image processor of type `ViTImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/476 [00:00<?, ?it/s]
# VisionEncoderDecoderModel LOAD REPORT from: microsoft/trocr-base-stage1
# Key                                                 | Status     |
# ----------------------------------------------------+------------+-
# decoder.model.decoder.embed_positions._float_tensor | UNEXPECTED |
# encoder.pooler.dense.bias                           | MISSING    |
# encoder.pooler.dense.weight                         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [Export] Base model: microsoft/trocr-base-stage1
# [Export] Vocab: 254 tokens | Newly added: 254
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The new lm_head weights will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# [Export] Decoder embeddings resized → 50381
# [Export] ViT pos embed: (24×24) → (8×96) | image_size=(128, 1536)
# [Export] Loaded: /content/drive/MyDrive/OCR/checkpoints/stage2b_best.pt
# [Export]   Epoch:    14
# [Export]   Metrics:  {'printed_cer': 0.021174453493356192, 'printed_wer': 0.05322475834619446, 'handwritten_cer': 0.14396028681742967, 'handwritten_wer': 0.26116551229997614}
# [Export]   Best CER: 0.14396028681742967
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Final model exported → /content/drive/MyDrive/OCR/checkpoints/final_model
#   config.json: 0.0 MB
#   generation_config.json: 0.0 MB
#   model.safetensors: 1541.1 MB
#   processor_config.json: 0.0 MB
#   tokenizer.json: 3.6 MB
#   tokenizer_config.json: 0.0 MB
#
# ── Validation: reloading exported model ──
# Loading weights:   0%|          | 0/478 [00:00<?, ?it/s]
#   Tokenizer: 'Đại học Tôn Đức Thắng' → ['Đ', 'ạ', 'i', 'Ġ', 'h', 'ọ', 'c', 'Ġ', 'T', 'ô', 'n', 'Ġ', 'Đ', 'ứ', 'c', 'Ġ', 'T', 'h', 'ắ', 'n', 'g']
#   Encoder: 86,800,896 params | Decoder: 298,448,896 params
#   Weight identity check: PASSED
#
# ✅ Validation passed — model is ready for inference.
#    Path: /content/drive/MyDrive/OCR/checkpoints/final_model
